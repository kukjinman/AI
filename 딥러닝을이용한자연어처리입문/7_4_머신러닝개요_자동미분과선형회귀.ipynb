# %%
import tensorflow as tf

w = tf.Variable(2.)

def f(w):
  y = w**2
  z = 2*y + 5
  return z


with tf.GradientTape() as tape:
  z = f(w)

gradients = tape.gradient(z, [w])
print(gradients)
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=8.0>]

# %%
type(gradients)
# Out:
# list

# %%
type(w)
# Out:
# tensorflow.python.ops.resource_variable_ops.ResourceVariable

# %%
type(z)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
w = tf.Variable(4.0)
b = tf.Variable(1.0)

# %%
@tf.function
def hypothesis(x):
  return w*x + b

# %%
x_test = [3.5, 5, 5.5, 6]
print(hypothesis(x_test).numpy())
# Out:
# [15. 21. 23. 25.]

# %%
def mse_loss(y_pred, y):
  # 두 개의 차이값을 제곱을 해서 평균을 취한다.
  return tf.reduce_mean(tf.square(y_pred - y))

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9] # 공부하는 시간
y = [11, 22, 33, 44, 53, 66, 77, 87, 95] # 각 공부하는 시간에 맵핑되는 성적

# %%
optimizer = tf.optimizers.SGD(0.01)

# %%
for i in range(301):
  with tf.GradientTape() as tape:
    # 현재 파라미터에 기반한 입력 x에 대한 예측값을 y_pred
    y_pred = hypothesis(x)

    # 평균 제곱 오차를 계산
    cost = mse_loss(y_pred, y)

  # 손실 함수에 대한 파라미터의 미분값 계산
  gradients = tape.gradient(cost, [w, b])
  print("test11:" , " w :  " ,w.numpy() , " b : " , b.numpy() , " cost : " , format(cost),"\n")

  # 파라미터 업데이트
  test = optimizer.apply_gradients(zip(gradients, [w, b]))
  print("test" , " w :  " ,w.numpy() , " b.numpy() : " , b.numpy() , " cost : " , format(cost),"\n")
    
  if i % 10 == 0:
    print("epoch : {:3} | w의 값 : {:5.4f} | b의 값 : {:5.4} | cost : {:5.6f}".format(i, w.numpy(), b.numpy(), cost))
# Out:
# test11:  w :   10.68333  b :  0.8055763  cost :  1.0598750114440918
#
# test  w :   10.68333  b.numpy() :  0.8055763  cost :  1.0598750114440918
#
# epoch :   0 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# test11:  w :   10.68333  b :  0.8055763  cost :  1.0598750114440918
#
# test  w :   10.68333  b.numpy() :  0.8055763  cost :  1.0598750114440918
#
# test11:  w :   10.68333  b :  0.8055763  cost :  1.0598750114440918
#
# test  w :   10.68333  b.numpy() :  0.8055763  cost :  1.0598750114440918
#
# test11:  w :   10.68333  b :  0.8055763  cost :  1.0598750114440918
#
# test  w :   10.68333  b.numpy() :  0.8055763  cost :  1.0598750114440918
#
# test11:  w :   10.68333  b :  0.8055763  cost :  1.0598750114440918
#
# test  w :   10.68333  b.numpy() :  0.8055763  cost :  1.0598750114440918
#
# test11:  w :   10.68333  b :  0.8055763  cost :  1.0598750114440918
#
# test  w :   10.68333  b.numpy() :  0.8055763  cost :  1.0598750114440918
#
# ...

# %%
for i in range(301):
  with tf.GradientTape() as tape:
    # 현재 파라미터에 기반한 입력 x에 대한 예측값을 y_pred
    y_pred = hypothesis(x)

    # 평균 제곱 오차를 계산
    cost = mse_loss(y_pred, y)

  # 손실 함수에 대한 파라미터의 미분값 계산
  gradients = tape.gradient(cost, [w, b])
  #print("test11:" , format(gradients) , " w :  " ,w.numpy() , " b : " , b.numpy() , " cost : " , format(cost),"\n\n")

  # 파라미터 업데이트
  test = optimizer.apply_gradients(zip(gradients, [w, b]))
  #print("test" , format(test), " w :  " ,w.numpy() , " b.numpy() : " , b.numpy() , " cost : " , format(cost),"\n\n")
    
  if i % 10 == 0:
    print("epoch : {:3} | w의 값 : {:5.4f} | b의 값 : {:5.4} | cost : {:5.6f}".format(i, w.numpy(), b.numpy(), cost))
# Out:
# epoch :   0 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch :  10 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch :  20 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch :  30 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch :  40 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch :  50 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch :  60 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch :  70 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch :  80 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch :  90 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch : 100 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch : 110 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch : 120 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch : 130 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# epoch : 140 | w의 값 : 10.6833 | b의 값 : 0.8056 | cost : 1.059875
# ...

# %%
type(optimizer)
# Out:
# keras.optimizer_v2.gradient_descent.SGD

# %%
import numpy as np
import matplotlib.pyplot as plt 

xn = np.array(x)
yn = np.array(y)


plt.plot(xn,yn )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 

def mse_loss(y_pred, y):
  # 두 개의 차이값을 제곱을 해서 평균을 취한다.
  return tf.reduce_mean(tf.square(y_pred - y))

x = [1, 2, 3, 4, 5, 6, 7, 8, 9] # 공부하는 시간
y = [11, 22, 33, 44, 53, 66, 77, 87, 95] # 각 공부하는 시간에 맵핑되는 성적

optimizer = tf.optimizers.SGD(0.01)

w1 = tf.Variable(4.0)
b1 = tf.Variable(1.0)

for i in range(301):
  with tf.GradientTape() as tape:
    # 현재 파라미터에 기반한 입력 x에 대한 예측값을 y_pred
    y_pred = hypothesis(x)

    # 평균 제곱 오차를 계산
    cost = mse_loss(y_pred, y)

  # 손실 함수에 대한 파라미터의 미분값 계산
  gradients = tape.gradient(cost, [w1, b1])
  #print("test11:" , format(gradients) , " w :  " ,w.numpy() , " b : " , b.numpy() , " cost : " , format(cost),"\n\n")

  # 파라미터 업데이트
  test = optimizer.apply_gradients(zip(gradients, [w1, b1]))
  #print("test" , format(test), " w :  " ,w.numpy() , " b.numpy() : " , b.numpy() , " cost : " , format(cost),"\n\n")
    
  if i % 10 == 0:
    print("epoch : {:3} | w의 값 : {:5.4f} | b의 값 : {:5.4} | cost : {:5.6f}".format(i, w1.numpy(), b1.numpy(), cost))
    xp = np.array(x)
    yp = w1*xp + b1
    plt.plot(xp,yp )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-127b75d797ba> in <module>
#      27
#      28   # 파라미터 업데이트
# ---> 29   test = optimizer.apply_gradients(zip(gradients, [w1, b1]))
#      30   #print("test" , format(test), " w :  " ,w.numpy() , " b.numpy() : " , b.numpy() , " cost : " , format(cost),"\n\n")
#      31
#
# D:\ProgramData\Anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     620       RuntimeError: If called in a cross-replica context.
#     621     """
# --> 622     grads_and_vars = optimizer_utils.filter_empty_gradients(grads_and_vars)
#     623     var_list = [v for (_, v) in grads_and_vars]
#     624
#
# D:\ProgramData\Anaconda3\lib\site-packages\keras\optimizer_v2\utils.py in filter_empty_gradients(grads_and_vars)
#      70
# ...

# %%
import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt 

# 학습될 가중치 변수를 선언
w = tf.Variable(4.0)
b = tf.Variable(1.0)

@tf.function
def hypothesis(x):
  return w*x + b

@tf.function
def mse_loss(y_pred, y):
  # 두 개의 차이값을 제곱을 해서 평균을 취한다.
  return tf.reduce_mean(tf.square(y_pred - y))


x = [1, 2, 3, 4, 5, 6, 7, 8, 9] # 공부하는 시간
y = [11, 22, 33, 44, 53, 66, 77, 87, 95] # 각 공부하는 시간에 맵핑되는 성적

optimizer = tf.optimizers.SGD(0.01)

for i in range(301):
  with tf.GradientTape() as tape:
    # 현재 파라미터에 기반한 입력 x에 대한 예측값을 y_pred
    y_pred = hypothesis(x)

    # 평균 제곱 오차를 계산
    cost = mse_loss(y_pred, y)

  # 손실 함수에 대한 파라미터의 미분값 계산
  gradients = tape.gradient(cost, [w, b])

  # 파라미터 업데이트
  optimizer.apply_gradients(zip(gradients, [w, b]))

  if i % 10 == 0:
    print("epoch : {:3} | w의 값 : {:5.4f} | b의 값 : {:5.4} | cost : {:5.6f}".format(i, w.numpy(), b.numpy(), cost))
    xp = np.array(x)
    yp = w*xp + b
    if(i == 0):
        plt.plot(xp,yp ,'r')
    else : 
        plt.plot(xp,yp ,'b')
# Out:
# epoch :   0 | w의 값 : 8.2133 | b의 값 : 1.664 | cost : 1402.555542
# epoch :  10 | w의 값 : 10.4971 | b의 값 : 1.977 | cost : 1.351182
# epoch :  20 | w의 값 : 10.5047 | b의 값 :  1.93 | cost : 1.328165
# epoch :  30 | w의 값 : 10.5119 | b의 값 : 1.884 | cost : 1.306967
# epoch :  40 | w의 값 : 10.5188 | b의 값 : 1.841 | cost : 1.287436
# epoch :  50 | w의 값 : 10.5254 | b의 값 : 1.799 | cost : 1.269459
# epoch :  60 | w의 값 : 10.5318 | b의 값 : 1.759 | cost : 1.252898
# epoch :  70 | w의 값 : 10.5379 | b의 값 : 1.721 | cost : 1.237644
# epoch :  80 | w의 값 : 10.5438 | b의 값 : 1.684 | cost : 1.223598
# epoch :  90 | w의 값 : 10.5494 | b의 값 : 1.648 | cost : 1.210658
# epoch : 100 | w의 값 : 10.5548 | b의 값 : 1.614 | cost : 1.198740
# epoch : 110 | w의 값 : 10.5600 | b의 값 : 1.582 | cost : 1.187767
# epoch : 120 | w의 값 : 10.5650 | b의 값 :  1.55 | cost : 1.177665
# epoch : 130 | w의 값 : 10.5697 | b의 값 :  1.52 | cost : 1.168354
# epoch : 140 | w의 값 : 10.5743 | b의 값 : 1.492 | cost : 1.159782
# ...

# %%
##케라스로 구현하는 선형회귀

import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers

x = [1, 2, 3, 4, 5, 6, 7, 8, 9] # 공부하는 시간
y = [11, 22, 33, 44, 53, 66, 77, 87, 95] # 각 공부하는 시간에 맵핑되는 성적

model = Sequential()

# 입력 x의 차원은 1, 출력 y의 차원도 1. 선형 회귀이므로 activation은 'linear'
model.add(Dense(1, input_dim=1, activation='linear'))

# sgd는 경사 하강법을 의미. 학습률(learning rate, lr)은 0.01.
sgd = optimizers.SGD(lr=0.01)

# 손실 함수(Loss function)은 평균제곱오차 mse를 사용.
model.compile(optimizer=sgd ,loss='mse',metrics=['mse'])

# 주어진 x와 y데이터에 대해서 오차를 최소화하는 작업을 300번 시도.
model.fit(x, y, epochs=300)

plt.plot(x, model.predict(x), 'b', x, y, 'k.')


## predict는 학습이 완료된 모델에서 입력data가 어떤 값을 예측하는지 
print(model.predict([9.5]))
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/300
# 1/1 [==============================] - 2s 2s/step - loss: 3304.6194 - mse: 3304.6194
# Epoch 2/300
# 1/1 [==============================] - 0s 6ms/step - loss: 407.6488 - mse: 407.6488
# Epoch 3/300
# 1/1 [==============================] - 0s 3ms/step - loss: 51.1973 - mse: 51.1973
# Epoch 4/300
# 1/1 [==============================] - 0s 5ms/step - loss: 7.3378 - mse: 7.3378
# Epoch 5/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9403 - mse: 1.9403
# Epoch 6/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2753 - mse: 1.2753
# Epoch 7/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1926 - mse: 1.1926
# Epoch 8/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1815 - mse: 1.1815
# Epoch 9/300
# ...
