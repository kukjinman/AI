# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
ages = [20,22,23,36,80,42,39,32,29,45,62,48,37,70]
bins = [18,25,35,60,100]
cdata = pd.cut(ages,bins)
pd.value_counts(cdata)
# Out:
# (35, 60]     6
# (60, 100]    3
# (18, 25]     3
# (25, 35]     2
# dtype: int64

# %%
cdata2 = pd.cut(ages,bins)
cdata2
# Out:
# [(18, 25], (18, 25], (18, 25], (35, 60], (60, 100], ..., (35, 60], (60, 100], (35, 60], (35, 60], (60, 100]]
# Length: 14
# Categories (4, interval[int64]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
cdata2 = pd.cut(ages,bins,right= False)
cdata2
# Out:
# [[18, 25), [18, 25), [18, 25), [35, 60), [60, 100), ..., [35, 60), [60, 100), [35, 60), [35, 60), [60, 100)]
# Length: 14
# Categories (4, interval[int64]): [[18, 25) < [25, 35) < [35, 60) < [60, 100)]

# %%
cdata3 = pd.cut(ages,bins, labels=['Youth','YoungAdult','MiddleAged','Senior'])
cdata3
# Out:
# ['Youth', 'Youth', 'Youth', 'MiddleAged', 'Senior', ..., 'MiddleAged', 'Senior', 'MiddleAged', 'MiddleAged', 'Senior']
# Length: 14
# Categories (4, object): ['Youth' < 'YoungAdult' < 'MiddleAged' < 'Senior']

# %%
pd.value_counts(cdata3)
# Out:
# MiddleAged    6
# Senior        3
# Youth         3
# YoungAdult    2
# dtype: int64

# %%
pd.value_counts(cdata3).sort_values()
# Out:
# YoungAdult    2
# Senior        3
# Youth         3
# MiddleAged    6
# dtype: int64

# %%
df = pd.DataFrame({'key1':['a','a','b','b','a'],
                   'key2':['one','two','one','two','one'],
                   'data1':np.random.randn(5),
                   'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.529830 -0.284202
# 1    a  two  1.943575  0.481663
# 2    b  one  0.210505 -0.676447
# 3    b  two -1.968898  0.733864
# 4    a  one -0.435265 -0.763925

# %%
grouped1 = df.groupby('key1')
grouped1.mean()
# Out:
#          data1     data2
# key1
# a     0.679380 -0.188822
# b    -0.879196  0.028709

# %%
grouped1 = df.groupby(['key1','key2'])
grouped1.mean()
# Out:
#               data1     data2
# key1 key2
# a    one   0.616763 -0.103248
#      two  -1.224757 -0.160947
# b    one   1.378880 -1.694911
#      two  -1.478402  1.268604

# %%
for name,data in grouped1 :
    print(name)
    print(data, end = '\n\n')
# Out:
# ('a', 'one')
#   key1 key2     data1     data2
# 0    a  one  1.050677  0.193412
# 4    a  one  0.182850 -0.399909
#
# ('a', 'two')
#   key1 key2     data1     data2
# 1    a  two -1.224757 -0.160947
#
# ('b', 'one')
#   key1 key2    data1     data2
# 2    b  one  1.37888 -1.694911
#
# ('b', 'two')
#   key1 key2     data1     data2
# 3    b  two -1.478402  1.268604

# %%
for g in grouped1 :

    print(g, end = '\n\n')
# Out:
# (('a', 'one'),   key1 key2     data1     data2
# 0    a  one  1.050677  0.193412
# 4    a  one  0.182850 -0.399909)
#
# (('a', 'two'),   key1 key2     data1     data2
# 1    a  two -1.224757 -0.160947)
#
# (('b', 'one'),   key1 key2    data1     data2
# 2    b  one  1.37888 -1.694911)
#
# (('b', 'two'),   key1 key2     data1     data2
# 3    b  two -1.478402  1.268604)

# %%
for (n1,n2),data in grouped1 :
    print(n1,'\n')
    print(n2,'\n')
    print(data, end = '\n\n')
# Out:
# a
#
# one
#
#   key1 key2     data1     data2
# 0    a  one  1.050677  0.193412
# 4    a  one  0.182850 -0.399909
#
# a
#
# two
#
#   key1 key2     data1     data2
# 1    a  two -1.224757 -0.160947
#
# b
#
# one
#
#   key1 key2    data1     data2
# 2    b  one  1.37888 -1.694911
#
# b
#
# two
#
#   key1 key2     data1     data2
# 3    b  two -1.478402  1.268604

# %%
for g in grouped1 :

    print(g)
# Out:
# (('a', 'one'),   key1 key2     data1     data2
# 0    a  one  1.050677  0.193412
# 4    a  one  0.182850 -0.399909)
# (('a', 'two'),   key1 key2     data1     data2
# 1    a  two -1.224757 -0.160947)
# (('b', 'one'),   key1 key2    data1     data2
# 2    b  one  1.37888 -1.694911)
# (('b', 'two'),   key1 key2     data1     data2
# 3    b  two -1.478402  1.268604)

# %%
list(grouped1)
# Out:
# [(('a', 'one'),
#     key1 key2     data1     data2
#   0    a  one  1.050677  0.193412
#   4    a  one  0.182850 -0.399909),
#  (('a', 'two'),
#     key1 key2     data1     data2
#   1    a  two -1.224757 -0.160947),
#  (('b', 'one'),
#     key1 key2    data1     data2
#   2    b  one  1.37888 -1.694911),
#  (('b', 'two'),
#     key1 key2     data1     data2
#   3    b  two -1.478402  1.268604)]

# %%
grouped1 = df.groupby('key1')
grouped1.mean()

gdata = dict(list(grouped1))
gdata['b']
# Out:
#   key1 key2     data1     data2
# 2    b  one  0.210505 -0.676447
# 3    b  two -1.968898  0.733864

# %%
np.random.seed(12345)
frame1 = pd.DataFrame(np.random.randn(5,5),
                     index = ['joe','steve','jim','wes','travis'],
                     columns = list('abcde'))
frame1
# Out:
#                a         b         c         d         e
# joe    -0.204708  0.478943 -0.519439 -0.555730  1.965781
# steve   1.393406  0.092908  0.281746  0.769023  1.246435
# jim     1.007189 -1.296221  0.274992  0.228913  1.352917
# wes     0.886429 -2.001637 -0.371843  1.669025 -0.438570
# travis -0.539741  0.476985  3.248944 -1.021228 -0.577087

# %%
mapping = {'a':'red','b':'red','c':'blue','d':'blue','e':'red'}
grouped4 = frame1.groupby(mapping, axis = 1)
list(grouped4)
# Out:
# [('blue',
#                  c         d
#   joe    -0.519439 -0.555730
#   steve   0.281746  0.769023
#   jim     0.274992  0.228913
#   wes    -0.371843  1.669025
#   travis  3.248944 -1.021228),
#  ('red',
#                  a         b         e
#   joe    -0.204708  0.478943  1.965781
#   steve   1.393406  0.092908  1.246435
#   jim     1.007189 -1.296221  1.352917
#   wes     0.886429 -2.001637 -0.438570
#   travis -0.539741  0.476985 -0.577087)]

# %%
grouped4.sum()
# Out:
#             blue       red
# joe    -1.075169  2.240016
# steve   1.050769  2.732748
# jim     0.503905  1.063885
# wes     1.297183 -1.553778
# travis  2.227716 -0.639844

# %%
label_list = ['one','one','one','two','two']
list(frame1.groupby(label_list))
# Out:
# [('one',
#                 a         b         c         d         e
#   joe   -0.204708  0.478943 -0.519439 -0.555730  1.965781
#   steve  1.393406  0.092908  0.281746  0.769023  1.246435
#   jim    1.007189 -1.296221  0.274992  0.228913  1.352917),
#  ('two',
#                  a         b         c         d         e
#   wes     0.886429 -2.001637 -0.371843  1.669025 -0.438570
#   travis -0.539741  0.476985  3.248944 -1.021228 -0.577087)]

# %%
frame1.groupby(label_list).sum()
# Out:
#             a         b         c         d         e
# one  2.195888 -0.724370  0.037299  0.442205  4.565132
# two  0.346688 -1.524652  2.877101  0.647798 -1.015657

# %%
frame1.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3  1.688911 -2.818915 -0.616290  1.342208  2.880128
# 5  1.393406  0.092908  0.281746  0.769023  1.246435
# 6 -0.539741  0.476985  3.248944 -1.021228 -0.577087

# %%
list(frame1.groupby([len,label_list]))
# Out:
# [((3, 'one'),
#               a         b         c         d         e
#   joe -0.204708  0.478943 -0.519439 -0.555730  1.965781
#   jim  1.007189 -1.296221  0.274992  0.228913  1.352917),
#  ((3, 'two'),
#               a         b         c         d        e
#   wes  0.886429 -2.001637 -0.371843  1.669025 -0.43857),
#  ((5, 'one'),
#                 a         b         c         d         e
#   steve  1.393406  0.092908  0.281746  0.769023  1.246435),
#  ((6, 'two'),
#                  a         b         c         d         e
#   travis -0.539741  0.476985  3.248944 -1.021228 -0.577087)]

# %%
frame1.groupby([len,label_list]).sum()
# Out:
#               a         b         c         d         e
# 3 one  0.802482 -0.817278 -0.244447 -0.326817  3.318697
#   two  0.886429 -2.001637 -0.371843  1.669025 -0.438570
# 5 one  1.393406  0.092908  0.281746  0.769023  1.246435
# 6 two -0.539741  0.476985  3.248944 -1.021228 -0.577087

# %%
tips = pd.read_csv('tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips['tip_pct']= tips['tip']/ tips['total_bill']
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]

# %%
grouped = tips.groupby(['sex','smoker'])
list(grouped)
# Out:
# [(('Female', 'No'),
#        total_bill   tip     sex smoker   day    time  size   tip_pct
#   0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
#   4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
#   11        35.26  5.00  Female     No   Sun  Dinner     4  0.141804
#   14        14.83  3.02  Female     No   Sun  Dinner     2  0.203641
#   16        10.33  1.67  Female     No   Sun  Dinner     3  0.161665
#   18        16.97  3.50  Female     No   Sun  Dinner     3  0.206246
#   21        20.29  2.75  Female     No   Sat  Dinner     2  0.135535
#   22        15.77  2.23  Female     No   Sat  Dinner     2  0.141408
#   29        19.65  3.00  Female     No   Sat  Dinner     2  0.152672
#   32        15.06  3.00  Female     No   Sat  Dinner     2  0.199203
#   33        20.69  2.45  Female     No   Sat  Dinner     4  0.118415
#   37        16.93  3.07  Female     No   Sat  Dinner     3  0.181335
# ...

# %%
grouped_pct = grouped['tip_pct']
list(grouped_pct)
# Out:
# [(('Female', 'No'),
#   0      0.059447
#   4      0.146808
#   11     0.141804
#   14     0.203641
#   16     0.161665
#   18     0.206246
#   21     0.135535
#   22     0.141408
#   29     0.152672
#   32     0.199203
#   33     0.118415
#   37     0.181335
#   51     0.252672
#   52     0.149382
#   57     0.056797
#   66     0.150152
#   71     0.175747
#   74     0.149355
#   82     0.181728
#   85     0.148435
#   94     0.142857
#   104    0.195029
#   111    0.137931
#   114    0.155581
#   115    0.202195
#   117    0.140845
#   118    0.144811
#   119    0.121262
#   121    0.125186
#   124    0.201923
#   125    0.140940
#   127    0.137741
#   128    0.175747
#   131    0.139615
#   132    0.134288
#   133    0.163132
#   134    0.177985
#   135    0.146886
#   136    0.193611
#   137    0.141343
#   139    0.208967
#   140    0.200343
#   143    0.184843
#   144    0.139988
#   145    0.179641
#   146    0.072961
#   147    0.137321
#   155    0.172194
# ...

# %%
grouped_pct.mean()
# Out:
# sex     smoker
# Female  No        0.156921
#         Yes       0.182150
# Male    No        0.160669
#         Yes       0.152771
# Name: tip_pct, dtype: float64

# %%
grouped_pct.agg([('mean'),('std')])
# Out:
#                    mean       std
# sex    smoker
# Female No      0.156921  0.036421
#        Yes     0.182150  0.071595
# Male   No      0.160669  0.041849
#        Yes     0.152771  0.090588

# %%
grouped_pct.agg([('gmean','mean'),('gstd','std')])
# Out:
#                   gmean      gstd
# sex    smoker
# Female No      0.156921  0.036421
#        Yes     0.182150  0.071595
# Male   No      0.160669  0.041849
#        Yes     0.152771  0.090588

# %%
grouped.agg({'tip':'max', 'size':'sum'})
# Out:
#                 tip  size
# sex    smoker
# Female No       5.2   140
#        Yes      6.5    74
# Male   No       9.0   263
#        Yes     10.0   150

# %%
grouped.agg({'tip_pct':['mean','std','max'], 'size':['sum','min']})
# Out:
#                 tip_pct                     size
#                    mean       std       max  sum min
# sex    smoker
# Female No      0.156921  0.036421  0.252672  140   1
#        Yes     0.182150  0.071595  0.416667   74   1
# Male   No      0.160669  0.041849  0.291990  263   2
#        Yes     0.152771  0.090588  0.710345  150   1

# %%
def top(df, n = 5, column = 'tip_pct'):
    return df.sort_values(by = column)[-n:]
tips.groupby('smoker').apply(top)
# Out:
#             total_bill   tip     sex smoker   day    time  size   tip_pct
# smoker
# No     88        24.71  5.85    Male     No  Thur   Lunch     2  0.236746
#        185       20.69  5.00    Male     No   Sun  Dinner     5  0.241663
#        51        10.29  2.60  Female     No   Sun  Dinner     2  0.252672
#        149        7.51  2.00    Male     No  Thur   Lunch     2  0.266312
#        232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
# Yes    109       14.31  4.00  Female    Yes   Sat  Dinner     2  0.279525
#        183       23.17  6.50    Male    Yes   Sun  Dinner     4  0.280535
#        67         3.07  1.00  Female    Yes   Sat  Dinner     1  0.325733
#        178        9.60  4.00  Female    Yes   Sun  Dinner     2  0.416667
#        172        7.25  5.15    Male    Yes   Sun  Dinner     2  0.710345

# %%
tips.groupby(['smoker','day']).apply(top,n = 2, column = 'total_bill')
# Out:
#                  total_bill    tip     sex smoker   day    time  size  \
# smoker day
# No     Fri  91        22.49   3.50    Male     No   Fri  Dinner     2
#             94        22.75   3.25  Female     No   Fri  Dinner     2
#        Sat  59        48.27   6.73    Male     No   Sat  Dinner     4
#             212       48.33   9.00    Male     No   Sat  Dinner     4
#        Sun  112       38.07   4.00    Male     No   Sun  Dinner     3
#             156       48.17   5.00    Male     No   Sun  Dinner     6
#        Thur 85        34.83   5.17  Female     No  Thur   Lunch     4
#             142       41.19   5.00    Male     No  Thur   Lunch     5
# Yes    Fri  90        28.97   3.00    Male    Yes   Fri  Dinner     2
#             95        40.17   4.73    Male    Yes   Fri  Dinner     4
#        Sat  102       44.30   2.50  Female    Yes   Sat  Dinner     3
#             170       50.81  10.00    Male    Yes   Sat  Dinner     3
# ...

# %%
states = ['ohio', 'new york', 'vermont', 'florida',
         'oregon', 'nevada', 'califonia', 'idaho']
group_key = ['east'] * 4 + ['west'] * 4 

sdata1 = pd.Series(np.random.randn(8), index=states)
sdata1[['vermont', 'nevada', 'idaho']] = np.nan
sdata1
# Out:
# ohio         0.124121
# new york     0.302614
# vermont           NaN
# florida      0.000940
# oregon       1.343810
# nevada            NaN
# califonia   -0.831154
# idaho             NaN
# dtype: float64

# %%
list(sdata1.groupby(group_key))
# Out:
# [('east',
#   ohio        0.124121
#   new york    0.302614
#   vermont          NaN
#   florida     0.000940
#   dtype: float64),
#  ('west',
#   oregon       1.343810
#   nevada            NaN
#   califonia   -0.831154
#   idaho             NaN
#   dtype: float64)]

# %%
sdata1.groupby(group_key).mean()
# Out:
# east    0.142558
# west    0.256328
# dtype: float64

# %%
sdata1.groupby(group_key).apply(lambda g: g.fillna(g.mean()))
# Out:
# ohio         0.124121
# new york     0.302614
# vermont      0.142558
# florida      0.000940
# oregon       1.343810
# nevada       0.256328
# califonia   -0.831154
# idaho        0.256328
# dtype: float64

# %%
fill_values = {'east':0.5, 'west': -1}
sdata1.groupby(group_key).apply(lambda g:g.fillna(fill_values[g.name]))
# Out:
# ohio         0.124121
# new york     0.302614
# vermont      0.500000
# florida      0.000940
# oregon       1.343810
# nevada      -1.000000
# califonia   -0.831154
# idaho       -1.000000
# dtype: float64

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]

# %%
tips.pivot_table(index = ['sex'])
# Out:
#             size       tip   tip_pct  total_bill
# sex
# Female  2.459770  2.833448  0.166491   18.056897
# Male    2.630573  3.089618  0.157651   20.744076

# %%
tips.pivot_table(index = ['sex','smoker'])
# Out:
#                    size       tip   tip_pct  total_bill
# sex    smoker
# Female No      2.592593  2.773519  0.156921   18.105185
#        Yes     2.242424  2.931515  0.182150   17.977879
# Male   No      2.711340  3.113402  0.160669   19.791237
#        Yes     2.500000  3.051167  0.152771   22.284500

# %%
tips.pivot_table(index = ['sex','smoker'],aggfunc='sum')
# Out:
#                size     tip    tip_pct  total_bill
# sex    smoker
# Female No       140  149.77   8.473732      977.68
#        Yes       74   96.74   6.010962      593.27
# Male   No       263  302.00  15.584865     1919.75
#        Yes      150  183.07   9.166271     1337.07

# %%
tips.pivot_table(['tip_pct','size'],
                index = ['sex','day'],
                columns = ['smoker'],
                aggfunc='std')
# Out:
#                  size             tip_pct
# smoker             No       Yes        No       Yes
# sex    day
# Female Fri   0.707107  0.000000  0.031733  0.041294
#        Sat   0.751068  0.676123  0.037135  0.075450
#        Sun   0.997249  0.577350  0.046007  0.120247
#        Thur  1.228821  0.786796  0.030925  0.031535
# Male   Fri   0.000000  0.834523  0.024918  0.039855
#        Sat   0.787375  0.926040  0.040635  0.051455
#        Sun   1.051287  0.985611  0.041498  0.162937
#        Thur  1.147079  0.674949  0.047097  0.045764

# %%
fec = pd.read_csv('P00000001-ALL.csv')
fec.info()
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001731 entries, 0 to 1001730
# Data columns (total 16 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   cmte_id            1001731 non-null  object
#  1   cand_id            1001731 non-null  object
#  2   cand_nm            1001731 non-null  object
#  3   contbr_nm          1001731 non-null  object
#  4   contbr_city        1001712 non-null  object
#  5   contbr_st          1001727 non-null  object
#  6   contbr_zip         1001620 non-null  object
#  7   contbr_employer    988002 non-null   object
#  8   contbr_occupation  993301 non-null   object
#  9   contb_receipt_amt  1001731 non-null  float64
# ...

# %%
fec.head()
# Out:
#      cmte_id    cand_id             cand_nm           contbr_nm  \
# 0  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2  C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4  C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
#
#           contbr_city contbr_st   contbr_zip        contbr_employer  \
# 0              MOBILE        AL   3.6601e+08                RETIRED
# 1              MOBILE        AL   3.6601e+08                RETIRED
# 2              LANETT        AL  3.68633e+08  INFORMATION REQUESTED
# 3             PIGGOTT        AR  7.24548e+08                   NONE
# 4  HOT SPRINGS NATION        AR  7.19016e+08                   NONE
#
#        contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0                RETIRED              250.0        20-JUN-11          NaN
# ...

# %%
fec.pivot_table(index = ['cand_nm'])
# Out:
#                                 contb_receipt_amt       file_num
# cand_nm
# Bachmann, Michelle                     203.762190  755098.307686
# Cain, Herman                           350.488133  774883.293828
# Gingrich, Newt                         251.931290  769385.766983
# Huntsman, Jon                          771.017921  759813.436477
# Johnson, Gary Earl                     459.450243  773088.914100
# McCotter, Thaddeus G                   500.405405  762447.000000
# Obama, Barack                          224.847985  774889.008121
# Paul, Ron                              144.149966  779990.033807
# Pawlenty, Timothy                      934.150184  751913.332602
# Perry, Rick                           1356.280804  757053.220331
# Roemer, Charles E. 'Buddy' III          62.070530  757791.379054
# Romney, Mitt                           794.740686  773824.046946
# Santorum, Rick                         230.419260  775369.709337

# %%
fec.cand_nm.unique()
# Out:
# array(['Bachmann, Michelle', 'Romney, Mitt', 'Obama, Barack',
#        "Roemer, Charles E. 'Buddy' III", 'Pawlenty, Timothy',
#        'Johnson, Gary Earl', 'Paul, Ron', 'Santorum, Rick',
#        'Cain, Herman', 'Gingrich, Newt', 'McCotter, Thaddeus G',
#        'Huntsman, Jon', 'Perry, Rick'], dtype=object)

# %%
type(fec.cand_nm.unique())
# Out:
# numpy.ndarray

# %%
parties = {'Bachmann, Michelle':'Republican',
           'Cain, Herman':'Republican',
           'Gingrich, Newt':'Republican',
           'Huntsman, Jon':'Republican',
           'Johnson, Gary Earl':'Republican',
           'McCotter, Thaddeus G':'Republican',
           'Obama, Barack':'Democrat',
           'Paul, Ron':'Republican',
           'Pawlenty, Timothy':'Republican',
           'Perry, Rick':'Republican',
           "Roemer, Charles E. 'Buddy' III":'Republican',
           'Romney, Mitt':'Republican',
           'Santorum, Rick':'Republican'}
parties
# Out:
# {'Bachmann, Michelle': 'Republican',
#  'Cain, Herman': 'Republican',
#  'Gingrich, Newt': 'Republican',
#  'Huntsman, Jon': 'Republican',
#  'Johnson, Gary Earl': 'Republican',
#  'McCotter, Thaddeus G': 'Republican',
#  'Obama, Barack': 'Democrat',
#  'Paul, Ron': 'Republican',
#  'Pawlenty, Timothy': 'Republican',
#  'Perry, Rick': 'Republican',
#  "Roemer, Charles E. 'Buddy' III": 'Republican',
#  'Romney, Mitt': 'Republican',
#  'Santorum, Rick': 'Republican'}

# %%
pd1 = pd.DataFrame(list(parties.items()), columns=['cand_nm', 'party'])

pd.merge(fec,pd1, on = 'cand_nm')
# Out:
#           cmte_id    cand_id             cand_nm               contbr_nm  \
# 0       C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 1       C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 2       C00410118  P20002978  Bachmann, Michelle           SMITH, LANIER
# 3       C00410118  P20002978  Bachmann, Michelle        BLEVINS, DARONDA
# 4       C00410118  P20002978  Bachmann, Michelle      WARDENBURG, HAROLD
# ...           ...        ...                 ...                     ...
# 991470  C00500587  P20003281         Perry, Rick    GORMAN, CHRIS D. MR.
# 991471  C00500587  P20003281         Perry, Rick     DUFFY, DAVID A. MR.
# 991472  C00500587  P20003281         Perry, Rick     GRANE, BRYAN F. MR.
# 991473  C00500587  P20003281         Perry, Rick      TOLBERT, DARYL MR.
# 991474  C00500587  P20003281         Perry, Rick  ANDERSON, MARILEE MRS.
#
#                contbr_city contbr_st   contbr_zip  \
# ...

# %%
fec['party'] = fec.cand_nm.map(parties)
fec.head()
# Out:
#      cmte_id    cand_id             cand_nm           contbr_nm  \
# 0  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2  C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4  C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
#
#           contbr_city contbr_st   contbr_zip        contbr_employer  \
# 0              MOBILE        AL   3.6601e+08                RETIRED
# 1              MOBILE        AL   3.6601e+08                RETIRED
# 2              LANETT        AL  3.68633e+08  INFORMATION REQUESTED
# 3             PIGGOTT        AR  7.24548e+08                   NONE
# 4  HOT SPRINGS NATION        AR  7.19016e+08                   NONE
#
#   contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc memo_cd  \
# 0           RETIRED              250.0        20-JUN-11          NaN     NaN
# ...

# %%
fec.cand_nm.map(parties)
# Out:
# 0          Republican
# 1          Republican
# 2          Republican
# 3          Republican
# 4          Republican
#               ...
# 1001726    Republican
# 1001727    Republican
# 1001728    Republican
# 1001729    Republican
# 1001730    Republican
# Name: cand_nm, Length: 1001731, dtype: object

# %%
#map에는 func과 dict두가지를 넣어서 사용할 수 있다
#map에 dict을 넣을경우 해당 dataframe에서 key를 비교하여 return한다

# %%
fec.value_counts(['party'])
# Out:
# party
# Democrat      593746
# Republican    407985
# dtype: int64

# %%
fec.contb_receipt_amt.head(25)
# Out:
# 0      250.0
# 1       50.0
# 2      250.0
# 3      250.0
# 4      300.0
# 5      500.0
# 6      250.0
# 7      250.0
# 8      250.0
# 9      250.0
# 10     250.0
# 11     500.0
# 12     250.0
# 13     250.0
# 14     250.0
# 15     300.0
# 16     500.0
# 17    1000.0
# 18     250.0
# 19     300.0
# 20     500.0
# 21     250.0
# 22    2500.0
# 23    2500.0
# 24     150.0
# Name: contb_receipt_amt, dtype: float64

# %%
fec.contbr_occupation.value_counts().head(10)
# Out:
# RETIRED                                   234829
# INFORMATION REQUESTED                      35176
# ATTORNEY                                   34409
# HOMEMAKER                                  30199
# PHYSICIAN                                  23530
# INFORMATION REQUESTED PER BEST EFFORTS     21364
# ENGINEER                                   14372
# TEACHER                                    13998
# CONSULTANT                                 13335
# PROFESSOR                                  12565
# Name: contbr_occupation, dtype: int64

# %%
fec = fec[fec.contb_receipt_amt > 0]
fec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 991475 entries, 0 to 1001730
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   cmte_id            991475 non-null  object
#  1   cand_id            991475 non-null  object
#  2   cand_nm            991475 non-null  object
#  3   contbr_nm          991475 non-null  object
#  4   contbr_city        991457 non-null  object
#  5   contbr_st          991471 non-null  object
#  6   contbr_zip         991373 non-null  object
#  7   contbr_employer    983833 non-null  object
#  8   contbr_occupation  989133 non-null  object
#  9   contb_receipt_amt  991475 non-null  float64
#  10  contb_receipt_dt   991475 non-null  object
#  11  receipt_desc       5219 non-null    object
#  12  memo_cd            89461 non-null   object
#  13  memo_text          94274 non-null   object
#  14  form_tp            991475 non-null  object
# ...

# %%
occ_mapping = {
    'INFORMATION REQUESTED PER BEST EFFORTS':'NOT PROVIDED',
    'INFORMATION REQUESTED':'NOT PROVIDED',
    'INFORMATION REQUESTED (BEST EFFORTS)':'NOT PROVIDED',
    'C.E.O':'CEO',
    'C.E.O.':'CEO'
}

# %%
ddata = {'name' : 'kim', 'age': 40}

# %%
ddata['age'], ddata.get('age')
# Out:
# (40, 40)

# %%
ddata.get('address','no data')
# Out:
# 'no data'

# %%
occ_mapping = {
    'INFORMATION REQUESTED PER BEST EFFORTS':'NOT PROVIDED',
    'INFORMATION REQUESTED':'NOT PROVIDED',
    'INFORMATION REQUESTED (BEST EFFORTS)':'NOT PROVIDED',
    'C.E.O':'CEO',
    'C.E.O.':'CEO'
}

# %%
f = lambda x : occ_mapping.get(x,x)
fec.contbr_occupation = fec.contbr_occupation.map(f)

# %%
fec.contbr_occupation.value_counts().head(10)
# Out:
# RETIRED         233990
# NOT PROVIDED     57151
# ATTORNEY         34286
# HOMEMAKER        29931
# PHYSICIAN        23432
# ENGINEER         14334
# TEACHER          13990
# CONSULTANT       13273
# PROFESSOR        12555
# NOT EMPLOYED      9828
# Name: contbr_occupation, dtype: int64

# %%
# row 직업별 column 정당별 data 기부금 합산

# %%
by_occupation = fec.pivot_table('contb_receipt_amt',
                               index = 'contbr_occupation',
                               columns = 'party',
                               aggfunc = 'sum')
by_occupation
# Out:
# party                                Democrat  Republican
# contbr_occupation
#    MIXED-MEDIA ARTIST / STORYTELLER     100.0         NaN
#  AREA VICE PRESIDENT                    250.0         NaN
#  RESEARCH ASSOCIATE                     100.0         NaN
#  TEACHER                                500.0         NaN
#  THERAPIST                             3900.0         NaN
# ...                                       ...         ...
# ZOOKEEPER                                35.0         NaN
# ZOOLOGIST                               400.0         NaN
# ZOOLOGY EDUCATION                        25.0         NaN
# \NONE\                                    NaN       250.0
# ~                                         NaN        75.0
#
# [45063 rows x 2 columns]

# %%
type(by_occupation)
# Out:
# pandas.core.frame.DataFrame

# %%
over_2mm = by_occupation[by_occupation.sum(axis = 1) > 2000000]
over_2mm
# Out:
# party                 Democrat    Republican
# contbr_occupation
# ATTORNEY           11141982.97  7.477194e+06
# CEO                 2075974.79  4.233742e+06
# CONSULTANT          2459912.71  2.544725e+06
# ENGINEER             951525.55  1.818374e+06
# EXECUTIVE           1355161.05  4.138850e+06
# HOMEMAKER           4248875.80  1.363428e+07
# INVESTOR             884133.00  2.431769e+06
# LAWYER              3160478.87  3.912243e+05
# MANAGER              762883.22  1.444532e+06
# NOT PROVIDED        4866973.96  2.056547e+07
# OWNER               1001567.36  2.408287e+06
# PHYSICIAN           3735124.94  3.594320e+06
# PRESIDENT           1878509.95  4.720924e+06
# PROFESSOR           2165071.08  2.967027e+05
# REAL ESTATE          528902.09  1.625902e+06
# RETIRED            25305116.38  2.356124e+07
# SELF-EMPLOYED        672393.40  1.640253e+06

# %%
over_2mm.plot(kind = 'barh')
plt.show()

# %%
fec_mrbo = fec[fec.cand_nm.isin(['Obama', 'Barack', 'Romney', 'Mitt'])]
fec_mrbo
# Out:
# Empty DataFrame
# Columns: [cmte_id, cand_id, cand_nm, contbr_nm, contbr_city, contbr_st, contbr_zip, contbr_employer, contbr_occupation, contb_receipt_amt, contb_receipt_dt, receipt_desc, memo_cd, memo_text, form_tp, file_num, party]
# Index: []

# %%
def get_top_amounts(group, key, n=5):
    totals = group.groupby(key)['contb_receipt_amt'].sum()
    return totals.sort_values()[:n]

# %%
grouped = fec_mrbo.groupby('cand_nm')
grouped.apply(get_top_amounts, 'contbr_occupation', n = 7)
# Out:
# cand_nm        contbr_occupation
# Obama, Barack  ADMINISTRATION/INSTRUCTOR                 3.0
#                SR MGR                                    3.0
#                COMPUTER ASSISTANT                        3.0
#                SPRINKLER FITTER FIRE PROTECTION SPECI    3.0
#                LEAD UI/UX DEVELOPER                      3.0
#                LAN/WAN ANALYST                           3.0
#                POLICY/ LAWYER                            3.0
# Romney, Mitt   3RD GENERATION FAMILY BUSINESS OWNER      3.0
#                AFFORDABLE REAL ESTATE DEVELOPER          3.0
#                REMODELER & SEMI RETIRED                  3.0
#                IFC CONTRACTING SOLUTIONS                 3.0
#                INDEPENDENT PROFESSIONAL                  3.0
#                SCOTT GREENBAUM                           5.0
#                FINANCIAL INSTITUTION - CEO               5.0
# Name: contb_receipt_amt, dtype: float64

# %%
fec.cand_nm.isin(['Obama, Barack', 'Romney, Mitt'])
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1001726    False
# 1001727    False
# 1001728    False
# 1001729    False
# 1001730    False
# Name: cand_nm, Length: 991475, dtype: bool

# %%
fec_mrbo = fec[fec.cand_nm.isin(['Obama, Barack', 'Romney, Mitt'])]
fec_mrbo
# Out:
#           cmte_id    cand_id        cand_nm           contbr_nm contbr_city  \
# 411     C00431171  P80003353   Romney, Mitt  ELDERBAUM, WILLIAM         DPO
# 412     C00431171  P80003353   Romney, Mitt  ELDERBAUM, WILLIAM         DPO
# 413     C00431171  P80003353   Romney, Mitt    CARLSEN, RICHARD         APO
# 414     C00431171  P80003353   Romney, Mitt      DELUCA, PIERRE         APO
# 415     C00431171  P80003353   Romney, Mitt    SARGENT, MICHAEL         APO
# ...           ...        ...            ...                 ...         ...
# 701381  C00431445  P80003338  Obama, Barack      MOUNTS, ROBERT         APO
# 701382  C00431445  P80003338  Obama, Barack     TAITANO, TYRONE     HAGATNA
# 701383  C00431445  P80003338  Obama, Barack      TUCKER, PAMELA         APO
# 701384  C00431445  P80003338  Obama, Barack      MOUNTS, ROBERT         APO
# 701385  C00431445  P80003338  Obama, Barack         NEAL, AMBER         APO
#
# ...

# %%
bins = np.array([0,1,10,100,1000,10000,100000,1000000,10000000])
labels = pd.cut(fec_mrbo.contb_receipt_amt,bins)

grouped = fec_mrbo.groupby(['cand_nm',labels])
grouped.size().unstack(level = 0)
# Out:
# cand_nm              Obama, Barack  Romney, Mitt
# contb_receipt_amt
# (0, 1]                         493            77
# (1, 10]                      40070          3681
# (10, 100]                   372280         31853
# (100, 1000]                 153991         43357
# (1000, 10000]                22284         26186
# (10000, 100000]                  2             1
# (100000, 1000000]                3             0
# (1000000, 10000000]              4             0

# %%
# Out:
# 411         (10, 100]
# 412       (100, 1000]
# 413       (100, 1000]
# 414         (10, 100]
# 415         (10, 100]
#              ...
# 701381      (10, 100]
# 701382    (100, 1000]
# 701383        (1, 10]
# 701384      (10, 100]
# 701385    (100, 1000]
# Name: contb_receipt_amt, Length: 694282, dtype: category
# Categories (8, interval[int64]): [(0, 1] < (1, 10] < (10, 100] < (100, 1000] < (1000, 10000] < (10000, 100000] < (100000, 1000000] < (1000000, 10000000]]

# %%
bucket_sums = grouped.contb_receipt_amt.sum().unstack(level=0)

# %%
bucket_sums
# Out:
# cand_nm              Obama, Barack  Romney, Mitt
# contb_receipt_amt
# (0, 1]                      318.24         77.00
# (1, 10]                  337267.62      29819.66
# (10, 100]              20288981.41    1987783.76
# (100, 1000]            54798531.46   22363381.69
# (1000, 10000]          51753705.67   63942145.42
# (10000, 100000]           59100.00      12700.00
# (100000, 1000000]       1490683.08           NaN
# (1000000, 10000000]     7148839.76           NaN

# %%
bucket_sums.sum(axis = 1)
# Out:
# contb_receipt_amt
# (0, 1]                 3.952400e+02
# (1, 10]                3.670873e+05
# (10, 100]              2.227677e+07
# (100, 1000]            7.716191e+07
# (1000, 10000]          1.156959e+08
# (10000, 100000]        7.180000e+04
# (100000, 1000000]      1.490683e+06
# (1000000, 10000000]    7.148840e+06
# dtype: float64

# %%
normed_sums = bucket_sums.div(bucket_sums.sum(axis = 1), axis = 0)
normed_sums
# Out:
# cand_nm              Obama, Barack  Romney, Mitt
# contb_receipt_amt
# (0, 1]                    0.805182      0.194818
# (1, 10]                   0.918767      0.081233
# (10, 100]                 0.910769      0.089231
# (100, 1000]               0.710176      0.289824
# (1000, 10000]             0.447326      0.552674
# (10000, 100000]           0.823120      0.176880
# (100000, 1000000]         1.000000           NaN
# (1000000, 10000000]       1.000000           NaN

# %%
type(bucket_sums)
# Out:
# pandas.core.frame.DataFrame

# %%
normed_sums[:-2].plot(kind = 'barh', stacked= True)
# Out:
# <AxesSubplot:ylabel='contb_receipt_amt'>

# %%
from datetime import datetime

# %%
now = datetime.now()
now
# Out:
# datetime.datetime(2021, 12, 3, 4, 34, 0, 281960)

# %%
now2 = datetime(2021,10,11)
now2
# Out:
# datetime.datetime(2021, 10, 11, 0, 0)

# %%
delta = now2 - datetime(2017,10,8,8,15)
delta
# Out:
# datetime.timedelta(days=1463, seconds=56700)

# %%
delta.microseconds
# Out:
# 0

# %%
delta.seconds
# Out:
# 56700

# %%
stamp = datetime(2019,1,4)
stamp.strftime('%Y년-%m월-%d일')
# Out:
# '2019년-01월-04일'

# %%
from dateutil.parser import parse
parse('2018-01-02')
# Out:
# datetime.datetime(2018, 1, 2, 0, 0)

# %%
parse('2020, Jan 31, 00:00 PM')
# Out:
# datetime.datetime(2020, 1, 31, 12, 0)

# %%
dates = [datetime(2921,7,2),datetime(2921,7,4),datetime(2921,7,5),datetime(2921,7,6),datetime(2921,7,9),datetime(2921,7,10),]
ts = pd.Series([55,33,99,11,22,44], index = dates)

# %%
ts
# Out:
# 2921-07-02 00:00:00    55
# 2921-07-04 00:00:00    33
# 2921-07-05 00:00:00    99
# 2921-07-06 00:00:00    11
# 2921-07-09 00:00:00    22
# 2921-07-10 00:00:00    44
# dtype: int64

# %%
ts['2021-07-02'], ts['20210702']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2021-07-02'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-216-aac8c818ad07> in <module>
# ...

# %%
ts['7/2/2021']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '7/2/2021'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-215-199b6c1b97cf> in <module>
# ----> 1 ts['7/2/2021']
#
# ...

# %%
ts2 = pd.Series(np.random.randn(1000), index = pd. date_range('1/1/2020', periods = 1000))

# %%
ts2
# Out:
# 2020-01-01   -1.860761
# 2020-01-02   -0.860757
# 2020-01-03    0.560145
# 2020-01-04   -1.265934
# 2020-01-05    0.119827
#                 ...
# 2022-09-22   -0.342277
# 2022-09-23   -0.009813
# 2022-09-24    0.053072
# 2022-09-25   -0.041943
# 2022-09-26   -1.694312
# Freq: D, Length: 1000, dtype: float64

# %%
ts2['2021-05-11' : '2021-05-21']
# Out:
# 2021-05-11   -0.947872
# 2021-05-12    0.676294
# 2021-05-13   -0.653356
# 2021-05-14   -0.652295
# 2021-05-15    0.528828
# 2021-05-16    0.357793
# 2021-05-17    0.188649
# 2021-05-18    0.869417
# 2021-05-19   -0.050667
# 2021-05-20   -0.716365
# 2021-05-21   -0.103259
# Freq: D, dtype: float64

# %%
frame = pd.DataFrame(np.random.randn(100,4),
                     index = pd.date_range('1/1/2000', periods = 100, freq = 'W-WED'),
                    columns = ['seoul','busan','incheon','suwon'])

# %%
frame
# Out:
#                seoul     busan   incheon     suwon
# 2000-01-05 -0.362381  1.127453  2.183830 -1.186623
# 2000-01-12  0.334270 -1.028389 -0.168496 -0.998948
# 2000-01-19 -1.531151 -1.079111 -1.097732  0.405148
# 2000-01-26 -0.227228 -1.442792 -1.422575 -1.123165
# 2000-02-02  0.216205 -0.459849  0.333392 -0.254742
# ...              ...       ...       ...       ...
# 2001-10-31 -0.229331 -1.140330  0.439920 -0.823758
# 2001-11-07 -0.520930  0.350282  0.204395  0.133445
# 2001-11-14  0.327905  0.072153  0.131678 -1.297459
# 2001-11-21  0.997747  0.870955 -0.991253  0.151699
# 2001-11-28  1.266151 -0.202469  0.050718  0.639869
#
# [100 rows x 4 columns]

# %%
pd.date_range(end = '7/1/2015', periods = 20)
# Out:
# DatetimeIndex(['2015-06-12', '2015-06-13', '2015-06-14', '2015-06-15',
#                '2015-06-16', '2015-06-17', '2015-06-18', '2015-06-19',
#                '2015-06-20', '2015-06-21', '2015-06-22', '2015-06-23',
#                '2015-06-24', '2015-06-25', '2015-06-26', '2015-06-27',
#                '2015-06-28', '2015-06-29', '2015-06-30', '2015-07-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start = '4/1/2012', end = '4/12/2015', freq = '4h')
# Out:
# DatetimeIndex(['2012-04-01 00:00:00', '2012-04-01 04:00:00',
#                '2012-04-01 08:00:00', '2012-04-01 12:00:00',
#                '2012-04-01 16:00:00', '2012-04-01 20:00:00',
#                '2012-04-02 00:00:00', '2012-04-02 04:00:00',
#                '2012-04-02 08:00:00', '2012-04-02 12:00:00',
#                ...
#                '2015-04-10 12:00:00', '2015-04-10 16:00:00',
#                '2015-04-10 20:00:00', '2015-04-11 00:00:00',
#                '2015-04-11 04:00:00', '2015-04-11 08:00:00',
#                '2015-04-11 12:00:00', '2015-04-11 16:00:00',
#                '2015-04-11 20:00:00', '2015-04-12 00:00:00'],
#               dtype='datetime64[ns]', length=6637, freq='4H')

# %%
pd.date_range(start = '7/1/2012', periods = 20, freq = '1h30min')
# Out:
# DatetimeIndex(['2012-07-01 00:00:00', '2012-07-01 01:30:00',
#                '2012-07-01 03:00:00', '2012-07-01 04:30:00',
#                '2012-07-01 06:00:00', '2012-07-01 07:30:00',
#                '2012-07-01 09:00:00', '2012-07-01 10:30:00',
#                '2012-07-01 12:00:00', '2012-07-01 13:30:00',
#                '2012-07-01 15:00:00', '2012-07-01 16:30:00',
#                '2012-07-01 18:00:00', '2012-07-01 19:30:00',
#                '2012-07-01 21:00:00', '2012-07-01 22:30:00',
#                '2012-07-02 00:00:00', '2012-07-02 01:30:00',
#                '2012-07-02 03:00:00', '2012-07-02 04:30:00'],
#               dtype='datetime64[ns]', freq='90T')

# %%
pd.date_range(start = '4/1/2012', end = '12/1/2015', freq = 'BM')
# Out:
# DatetimeIndex(['2012-04-30', '2012-05-31', '2012-06-29', '2012-07-31',
#                '2012-08-31', '2012-09-28', '2012-10-31', '2012-11-30',
#                '2012-12-31', '2013-01-31', '2013-02-28', '2013-03-29',
#                '2013-04-30', '2013-05-31', '2013-06-28', '2013-07-31',
#                '2013-08-30', '2013-09-30', '2013-10-31', '2013-11-29',
#                '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31',
#                '2014-04-30', '2014-05-30', '2014-06-30', '2014-07-31',
#                '2014-08-29', '2014-09-30', '2014-10-31', '2014-11-28',
#                '2014-12-31', '2015-01-30', '2015-02-27', '2015-03-31',
#                '2015-04-30', '2015-05-29', '2015-06-30', '2015-07-31',
#                '2015-08-31', '2015-09-30', '2015-10-30', '2015-11-30'],
#               dtype='datetime64[ns]', freq='BM')

# %%
pd.date_range(start = '4/1/2012', end = '12/1/2014', freq = 'WOM-2FRI')
# Out:
# DatetimeIndex(['2012-04-13', '2012-05-11', '2012-06-08', '2012-07-13',
#                '2012-08-10', '2012-09-14', '2012-10-12', '2012-11-09',
#                '2012-12-14', '2013-01-11', '2013-02-08', '2013-03-08',
#                '2013-04-12', '2013-05-10', '2013-06-14', '2013-07-12',
#                '2013-08-09', '2013-09-13', '2013-10-11', '2013-11-08',
#                '2013-12-13', '2014-01-10', '2014-02-14', '2014-03-14',
#                '2014-04-11', '2014-05-09', '2014-06-13', '2014-07-11',
#                '2014-08-08', '2014-09-12', '2014-10-10', '2014-11-14'],
#               dtype='datetime64[ns]', freq='WOM-2FRI')

# %%
ts1 = pd.Series(np.arange(12), index = pd.date_range('1/1/2000', periods = 12, freq = 'T'))
ts1
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:01:00     1
# 2000-01-01 00:02:00     2
# 2000-01-01 00:03:00     3
# 2000-01-01 00:04:00     4
# 2000-01-01 00:05:00     5
# 2000-01-01 00:06:00     6
# 2000-01-01 00:07:00     7
# 2000-01-01 00:08:00     8
# 2000-01-01 00:09:00     9
# 2000-01-01 00:10:00    10
# 2000-01-01 00:11:00    11
# Freq: T, dtype: int64

# %%
ts1.resample('5min').sum()
# Out:
# 2000-01-01 00:00:00    10
# 2000-01-01 00:05:00    35
# 2000-01-01 00:10:00    21
# Freq: 5T, dtype: int64

# %%
ts1.resample('5min', closed = 'right').sum()
# Out:
# 1999-12-31 23:55:00     0
# 2000-01-01 00:00:00    15
# 2000-01-01 00:05:00    40
# 2000-01-01 00:10:00    11
# Freq: 5T, dtype: int64

# %%
ts1.resample('5min', closed = 'right', label = 'right').sum()
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:05:00    15
# 2000-01-01 00:10:00    40
# 2000-01-01 00:15:00    11
# Freq: 5T, dtype: int64

# %%
frame = pd.DataFrame(np.random.randn(2,4),
                    index=pd.date_range('1/1/2000',periods=2, freq='W-WED'),
                    columns=['seoul','busan','daegu','incheon'])
frame
# Out:
#                seoul     busan     daegu   incheon
# 2000-01-05  0.364287 -0.922839  0.312656 -1.128497
# 2000-01-12 -0.333488 -0.514551 -0.559782 -0.783408

# %%
frame.resample('D').ffill(limit = 2)
# Out:
#                seoul     busan     daegu   incheon
# 2000-01-05  0.364287 -0.922839  0.312656 -1.128497
# 2000-01-06  0.364287 -0.922839  0.312656 -1.128497
# 2000-01-07  0.364287 -0.922839  0.312656 -1.128497
# 2000-01-08       NaN       NaN       NaN       NaN
# 2000-01-09       NaN       NaN       NaN       NaN
# 2000-01-10       NaN       NaN       NaN       NaN
# 2000-01-11       NaN       NaN       NaN       NaN
# 2000-01-12 -0.333488 -0.514551 -0.559782 -0.783408

# %%
close_px_all = pd.read_csv('stock_px.csv', parse_dates=True, index_col = 0)
close_px_all.head()
# Out:
#             AAPL   MSFT    XOM     SPX
# 2003-01-02  7.40  21.11  29.22  909.03
# 2003-01-03  7.45  21.14  29.24  908.59
# 2003-01-06  7.45  21.52  29.96  929.01
# 2003-01-07  7.43  21.93  28.95  922.93
# 2003-01-08  7.28  21.31  28.83  909.93

# %%
close_px = close_px_all.drop('SPX', axis = 'columns')

# %%
close_px = close_px.resample('B').ffill()
close_px.head()
# Out:
#             AAPL   MSFT    XOM
# 2003-01-02  7.40  21.11  29.22
# 2003-01-03  7.45  21.14  29.24
# 2003-01-06  7.45  21.52  29.96
# 2003-01-07  7.43  21.93  28.95
# 2003-01-08  7.28  21.31  28.83
